# %%
import requests
import json



API_KEY = '697E5HZ5EUSDUJVYWDVHETCNW'
location = 'California'
start_date = '2021-01-01'
end_date = '2021-12-31'
unit_group = 'us'

url = f'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/California/2021-01-01/2021-12-31?unitGroup=us&elements=datetime%2Cname%2Ctempmax%2Ctempmin%2Ctemp%2Cfeelslike%2Chumidity%2Cprecip%2Cpreciptype%2Csnow%2Cwindspeed%2Cwindspeedmean%2Cvisibility%2Cconditions%2Cdescription&include=days&key=697E5HZ5EUSDUJVYWDVHETCNW&contentType=json'

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    with open("weather_data_CA.json", "w") as f:
        json.dump(data, f, indent=4)
    print("Data retrieved and saved to 'weather_data.json'")
else:
    print(f"API request failed with status code {response.status_code}")
# Out:
# Data retrieved and saved to 'weather_data.json'

# %%
import requests
import json

API_KEY = '697E5HZ5EUSDUJVYWDVHETCNW'
location = 'Connecticut'
start_date = '2021-01-01'
end_date = '2021-12-31'
unit_group = 'us'

url = f'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Connecticut/2021-01-01/2021-12-31?unitGroup=us&elements=datetime%2Cname%2Ctempmax%2Ctempmin%2Ctemp%2Cfeelslike%2Chumidity%2Cprecip%2Cpreciptype%2Csnow%2Cwindspeed%2Cwindspeedmean%2Cvisibility%2Cconditions%2Cdescription&include=days&key=697E5HZ5EUSDUJVYWDVHETCNW&contentType=json'

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    with open("weather_data_CT.json", "w") as f:
        json.dump(data, f, indent=4)
    print("Data retrieved and saved to 'weather_data_CT.json'")
else:
    print(f"API request failed with status code {response.status_code}")
# Out:
# Data retrieved and saved to 'weather_data_CT.json'

# %%
import requests
import json

API_KEY = '697E5HZ5EUSDUJVYWDVHETCNW'
location = 'Florida'
start_date = '2021-01-01'
end_date = '2021-12-31'
unit_group = 'us'

url = f'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Florida%20/2021-01-01/2021-12-31?unitGroup=us&elements=datetime%2Cname%2Ctempmax%2Ctempmin%2Ctemp%2Cfeelslike%2Chumidity%2Cprecip%2Cpreciptype%2Csnow%2Cwindspeed%2Cwindspeedmean%2Cvisibility%2Cconditions%2Cdescription&include=days&key=697E5HZ5EUSDUJVYWDVHETCNW&contentType=json'
response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    with open("weather_data_FL.json", "w") as f:
        json.dump(data, f, indent=4)
    print("Data retrieved and saved to 'weather_data_FL.json'")
else:
    print(f"API request failed with status code {response.status_code}")
# Out:
# Data retrieved and saved to 'weather_data_FL.json'

# %%
import requests
import json

API_KEY = '697E5HZ5EUSDUJVYWDVHETCNW'
location = 'Georgia'
start_date = '2021-01-01'
end_date = '2021-12-31'
unit_group = 'us'

url = f'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Georgia/2021-01-01/2021-12-31?unitGroup=us&elements=datetime%2Cname%2Ctempmax%2Ctempmin%2Ctemp%2Cfeelslike%2Chumidity%2Cprecip%2Cpreciptype%2Csnow%2Cwindspeed%2Cwindspeedmean%2Cvisibility%2Cconditions%2Cdescription&include=days&key=697E5HZ5EUSDUJVYWDVHETCNW&contentType=json'

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    with open("weather_data_GA.json", "w") as f:
        json.dump(data, f, indent=4)
    print("Data retrieved and saved to 'weather_data_GA.json'")
else:
    print(f"API request failed with status code {response.status_code}")
# Out:
# Data retrieved and saved to 'weather_data_GA.json'

# %%
import requests
import json

API_KEY = '697E5HZ5EUSDUJVYWDVHETCNW'
location = 'Maryland'
start_date = '2021-01-01'
end_date = '2021-12-31'
unit_group = 'us'

url = f'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/%20Maryland/2021-01-01/2021-12-31?unitGroup=us&elements=datetime%2Cname%2Ctempmax%2Ctempmin%2Ctemp%2Cfeelslike%2Chumidity%2Cprecip%2Cpreciptype%2Csnow%2Cwindspeed%2Cwindspeedmean%2Cvisibility%2Cconditions%2Cdescription&include=days&key=697E5HZ5EUSDUJVYWDVHETCNW&contentType=json'

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    with open("weather_data_MD.json", "w") as f:
        json.dump(data, f, indent=4)
    print("Data retrieved and saved to 'weather_data_MD.json'")
else:
    print(f"API request failed with status code {response.status_code}")
# Out:
# Data retrieved and saved to 'weather_data_MD.json'

# %%
import requests
import json

API_KEY = '697E5HZ5EUSDUJVYWDVHETCNW'
location = 'Michigan'
start_date = '2021-01-01'
end_date = '2021-12-31'
unit_group = 'us'

url = f'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/%20Michigan%20/2021-01-01/2021-12-31?unitGroup=us&elements=datetime%2Cname%2Ctempmax%2Ctempmin%2Ctemp%2Cfeelslike%2Chumidity%2Cprecip%2Cpreciptype%2Csnow%2Cwindspeed%2Cwindspeedmean%2Cvisibility%2Cconditions%2Cdescription&include=days&key=697E5HZ5EUSDUJVYWDVHETCNW&contentType=json'

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    with open("weather_data_MI.json", "w") as f:
        json.dump(data, f, indent=4)
    print("Data retrieved and saved to 'weather_data_MI.json'")
else:
    print(f"API request failed with status code {response.status_code}")
# Out:
# Data retrieved and saved to 'weather_data_MI.json'

# %%
import requests
import json

API_KEY = '697E5HZ5EUSDUJVYWDVHETCNW'
location = 'New York'
start_date = '2021-01-01'
end_date = '2021-12-31'
unit_group = 'us'

url = f'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/New%20York%20/2021-01-01/2021-12-31?unitGroup=us&elements=datetime%2Cname%2Ctempmax%2Ctempmin%2Ctemp%2Cfeelslike%2Chumidity%2Cprecip%2Cpreciptype%2Csnow%2Cwindspeed%2Cwindspeedmean%2Cvisibility%2Cconditions%2Cdescription&include=days&key=697E5HZ5EUSDUJVYWDVHETCNW&contentType=json'

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    with open("weather_data_NY.json", "w") as f:
        json.dump(data, f, indent=4)
    print("Data retrieved and saved to 'weather_data_NY.json'")
else:
    print(f"API request failed with status code {response.status_code}")
# Out:
# Data retrieved and saved to 'weather_data_NY.json'

# %%
import requests
import json

API_KEY = '697E5HZ5EUSDUJVYWDVHETCNW'
location = 'Pennsylvania'
start_date = '2021-01-01'
end_date = '2021-12-31'
unit_group = 'us'

url = f'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Pennsylvania%20/2021-01-01/2021-12-31?unitGroup=us&elements=datetime%2Cname%2Ctempmax%2Ctempmin%2Ctemp%2Cfeelslike%2Chumidity%2Cprecip%2Cpreciptype%2Csnow%2Cwindspeed%2Cwindspeedmean%2Cvisibility%2Cconditions%2Cdescription&include=days&key=697E5HZ5EUSDUJVYWDVHETCNW&contentType=json'

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    with open("weather_data_PA.json", "w") as f:
        json.dump(data, f, indent=4)
    print("Data retrieved and saved to 'weather_data_PA.json'")
else:
    print(f"API request failed with status code {response.status_code}")
# Out:
# Data retrieved and saved to 'weather_data_PA.json'

# %%
import requests
import json

API_KEY = '697E5HZ5EUSDUJVYWDVHETCNW'
location = 'Texas'
start_date = '2021-01-01'
end_date = '2021-12-31'
unit_group = 'us'

url = f'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Texas%20/2021-01-01/2021-12-31?unitGroup=us&elements=datetime%2Cname%2Ctempmax%2Ctempmin%2Ctemp%2Cfeelslike%2Chumidity%2Cprecip%2Cpreciptype%2Csnow%2Cwindspeed%2Cwindspeedmean%2Cvisibility%2Cconditions%2Cdescription&include=days&key=697E5HZ5EUSDUJVYWDVHETCNW&contentType=json'

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    with open("weather_data_TX.json", "w") as f:
        json.dump(data, f, indent=4)
    print("Data retrieved and saved to 'weather_data_TX.json'")
else:
    print(f"API request failed with status code {response.status_code}")
# Out:
# Data retrieved and saved to 'weather_data_TX.json'

# %%
import requests
import json

API_KEY = '697E5HZ5EUSDUJVYWDVHETCNW'
location = 'Washington'
start_date = '2021-01-01'
end_date = '2021-12-31'
unit_group = 'us'

url = f'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Washington/2021-01-01/2021-12-31?unitGroup=us&elements=datetime%2Cname%2Ctempmax%2Ctempmin%2Ctemp%2Cfeelslike%2Chumidity%2Cprecip%2Cpreciptype%2Csnow%2Cwindspeed%2Cwindspeedmean%2Cvisibility%2Cconditions%2Cdescription&include=days&key=697E5HZ5EUSDUJVYWDVHETCNW&contentType=json'

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    with open("weather_data_WA.json", "w") as f:
        json.dump(data, f, indent=4)
    print("Data retrieved and saved to 'weather_data_WA.json'")
else:
    print(f"API request failed with status code {response.status_code}")
# Out:
# Data retrieved and saved to 'weather_data_WA.json'
